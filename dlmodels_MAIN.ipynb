# %% [markdown]
# <a href="https://colab.research.google.com/github/Aquib88raza/image-classification-ANKLE/blob/main/dlmodels_MAIN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from pathlib import Path
import os.path
import matplotlib.pyplot as plt
from IPython.display import Image, display, Markdown
import matplotlib.cm as cm
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import tensorflow as tf
from time import perf_counter
import seaborn as sns

def printmd(string):
    # Print with Markdowns
    display(Markdown(string))

# %%
# Define the image directory
image_dir = Path('/content/drive/MyDrive/newmodidata/Y2022Ankle')

# Get filepaths and labels
filepaths = list(image_dir.glob('**/*.jpg'))
labels = [os.path.split(os.path.split(x)[0])[1] for x in filepaths]

filepaths = pd.Series(filepaths, name='Filepath').astype(str)
labels = pd.Series(labels, name='Label')

# Concatenate filepaths and labels
image_df = pd.concat([filepaths, labels], axis=1)

# Shuffle the DataFrame and reset the index
image_df = image_df.sample(frac=1).reset_index(drop=True)

# Show the result
image_df.head(3)

# Display the number of pictures of each category
vc = image_df['Label'].value_counts()
plt.figure(figsize=(9,5))
sns.barplot(x=vc.index, y=vc, palette="rocket")
plt.title("Number of pictures of each category", fontsize=15)
plt.show()

# %%
def create_gen():
    # Load the Images with a generator and Data Augmentation
    train_generator = tf.keras.preprocessing.image.ImageDataGenerator(
        preprocessing_function=tf.keras.applications.mobilenet_v2.preprocess_input,
        validation_split=0.1
    )

    test_generator = tf.keras.preprocessing.image.ImageDataGenerator(
        preprocessing_function=tf.keras.applications.mobilenet_v2.preprocess_input
    )

    train_images = train_generator.flow_from_dataframe(
        dataframe=train_df,
        x_col='Filepath',
        y_col='Label',
        target_size=(224, 224),
        color_mode='rgb',
        class_mode='categorical',
        batch_size=32,
        shuffle=True,
        seed=0,
        subset='training',
        rotation_range=30, # Uncomment to use data augmentation
        zoom_range=0.15,
        width_shift_range=0.2,
        height_shift_range=0.2,
        shear_range=0.15,
        horizontal_flip=True,
        fill_mode="nearest"
    )

    val_images = train_generator.flow_from_dataframe(
        dataframe=train_df,
        x_col='Filepath',
        y_col='Label',
        target_size=(224, 224),
        color_mode='rgb',
        class_mode='categorical',
        batch_size=32,
        shuffle=True,
        seed=0,
        subset='validation',
        rotation_range=30, # Uncomment to use data augmentation
        zoom_range=0.15,
        width_shift_range=0.2,
        height_shift_range=0.2,
        shear_range=0.15,
        horizontal_flip=True,
        fill_mode="nearest"
    )

    test_images = test_generator.flow_from_dataframe(
        dataframe=test_df,
        x_col='Filepath',
        y_col='Label',
        target_size=(224, 224),
        color_mode='rgb',
        class_mode='categorical',
        batch_size=32,
        shuffle=False
    )

    return train_generator,test_generator,train_images,val_images,test_images

# %%
def get_model(model):
# Load the pretained model
    kwargs =    {'input_shape':(224, 224, 3),
                'include_top':False,
                'weights':'imagenet',
                'pooling':'avg'}

    pretrained_model = model(**kwargs)
    pretrained_model.trainable = False

    inputs = pretrained_model.input

    x = tf.keras.layers.Dense(128, activation='relu')(pretrained_model.output)
    x = tf.keras.layers.Dense(128, activation='relu')(x)

    outputs = tf.keras.layers.Dense(2, activation='softmax')(x)

    model = tf.keras.Model(inputs=inputs, outputs=outputs)

    model.compile(
        optimizer='adam',
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    return model

# %%
# Separate in train and test data
train_df, test_df = train_test_split(image_df, train_size=0.9, shuffle=True, random_state=1)

# %%
# Dictionary with the models
models = {
    "DenseNet121": {"model":tf.keras.applications.DenseNet121, "perf":0},
    "MobileNetV2": {"model":tf.keras.applications.MobileNetV2, "perf":0},
    "DenseNet169": {"model":tf.keras.applications.DenseNet169, "perf":0},
    "DenseNet201": {"model":tf.keras.applications.DenseNet201, "perf":0},
    "EfficientNetB0": {"model":tf.keras.applications.EfficientNetB0, "perf":0},
    "EfficientNetB1": {"model":tf.keras.applications.EfficientNetB1, "perf":0},
    "EfficientNetB2": {"model":tf.keras.applications.EfficientNetB2, "perf":0},
    "EfficientNetB3": {"model":tf.keras.applications.EfficientNetB3, "perf":0},
    "EfficientNetB4": {"model":tf.keras.applications.EfficientNetB4, "perf":0},
    "EfficientNetB5": {"model":tf.keras.applications.EfficientNetB4, "perf":0},
    "EfficientNetB6": {"model":tf.keras.applications.EfficientNetB4, "perf":0},
    "EfficientNetB7": {"model":tf.keras.applications.EfficientNetB4, "perf":0},
    "InceptionResNetV2": {"model":tf.keras.applications.InceptionResNetV2, "perf":0},
    "InceptionV3": {"model":tf.keras.applications.InceptionV3, "perf":0},
    "MobileNet": {"model":tf.keras.applications.MobileNet, "perf":0},
    "MobileNetV2": {"model":tf.keras.applications.MobileNetV2, "perf":0},
    "MobileNetV3Large": {"model":tf.keras.applications.MobileNetV3Large, "perf":0},
    "MobileNetV3Small": {"model":tf.keras.applications.MobileNetV3Small, "perf":0},
    "NASNetMobile": {"model":tf.keras.applications.NASNetMobile, "perf":0},
    "ResNet101": {"model":tf.keras.applications.ResNet101, "perf":0},
    "ResNet101V2": {"model":tf.keras.applications.ResNet101V2, "perf":0},
    "ResNet152": {"model":tf.keras.applications.ResNet152, "perf":0},
    "ResNet152V2": {"model":tf.keras.applications.ResNet152V2, "perf":0},
    "ResNet50": {"model":tf.keras.applications.ResNet50, "perf":0},
    "ResNet50V2": {"model":tf.keras.applications.ResNet50V2, "perf":0},
    "VGG16": {"model":tf.keras.applications.VGG16, "perf":0},
    "VGG19": {"model":tf.keras.applications.VGG19, "perf":0},
    "Xception": {"model":tf.keras.applications.Xception, "perf":0}
}

# Create the generators
train_generator,test_generator,train_images,val_images,test_images=create_gen()
print('\n')

# Fit the models
for name, model in models.items():

    # Get the model
    m = get_model(model['model'])
    models[name]['model'] = m

    start = perf_counter()

    # Fit the model
    history = m.fit(train_images,validation_data=val_images,epochs=1,verbose=1)

    # Sav the duration, the train_accuracy and the val_accuracy
    duration = perf_counter() - start
    duration = round(duration,2)
    models[name]['perf'] = duration
    print(f"{name:20} trained in {duration} sec")

    val_acc = history.history['val_accuracy']
    models[name]['val_acc'] = [round(v,4) for v in val_acc]

    train_acc = history.history['accuracy']
    models[name]['train_accuracy'] = [round(v,4) for v in train_acc]
# Out:
# Found 144 validated image filenames belonging to 2 classes.
# Found 16 validated image filenames belonging to 2 classes.
# Found 18 validated image filenames belonging to 2 classes.
#
#
# 5/5 [==============================] - 40s 7s/step - loss: 0.7776 - accuracy: 0.5486 - val_loss: 0.6723 - val_accuracy: 0.6875
# DenseNet121          trained in 40.37 sec
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 [==============================] - 0s 0us/step
# 5/5 [==============================] - 11s 1s/step - loss: 0.8606 - accuracy: 0.5000 - val_loss: 0.6367 - val_accuracy: 0.6875
# MobileNetV2          trained in 10.7 sec
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet169_weights_tf_dim_ordering_tf_kernels_notop.h5
# 51877672/51877672 [==============================] - 0s 0us/step
# 5/5 [==============================] - 45s 8s/step - loss: 0.7959 - accuracy: 0.5278 - val_loss: 0.5139 - val_accuracy: 0.8125
# DenseNet169          trained in 45.03 sec
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74836368/74836368 [==============================] - 1s 0us/step
# 5/5 [==============================] - 55s 9s/step - loss: 0.7289 - accuracy: 0.6111 - val_loss: 0.5759 - val_accuracy: 0.8125
# DenseNet201          trained in 93.22 sec
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 [==============================] - 0s 0us/step
# 5/5 [==============================] - ETA: 0s - loss: 0.7123 - accuracy: 0.5417
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_test_function.<locals>.test_function at 0x78db6843ac20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 5/5 [==============================] - 21s 3s/step - loss: 0.7123 - accuracy: 0.5417 - val_loss: 0.6981 - val_accuracy: 0.3125
# EfficientNetB0       trained in 28.19 sec
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb1_notop.h5
# 27018416/27018416 [==============================] - 0s 0us/step
# 5/5 [==============================] - ETA: 0s - loss: 0.7024 - accuracy: 0.5903
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_test_function.<locals>.test_function at 0x78db690c9870> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 5/5 [==============================] - 29s 4s/step - loss: 0.7024 - accuracy: 0.5903 - val_loss: 0.7264 - val_accuracy: 0.3125
# EfficientNetB1       trained in 30.15 sec
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb2_notop.h5
# 31790344/31790344 [==============================] - 0s 0us/step
# 5/5 [==============================] - 30s 4s/step - loss: 0.7203 - accuracy: 0.4861 - val_loss: 0.6779 - val_accuracy: 0.6875
# EfficientNetB2       trained in 30.78 sec
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb3_notop.h5
# 43941136/43941136 [==============================] - 0s 0us/step
# 5/5 [==============================] - 39s 6s/step - loss: 0.7018 - accuracy: 0.5694 - val_loss: 0.6180 - val_accuracy: 0.6875
# EfficientNetB3       trained in 38.7 sec
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb4_notop.h5
# 71686520/71686520 [==============================] - 1s 0us/step
# 5/5 [==============================] - 50s 7s/step - loss: 0.7163 - accuracy: 0.5208 - val_loss: 0.6558 - val_accuracy: 0.6875
# EfficientNetB4       trained in 55.68 sec
# 5/5 [==============================] - 50s 8s/step - loss: 0.6996 - accuracy: 0.6042 - val_loss: 0.7174 - val_accuracy: 0.3125
# EfficientNetB5       trained in 49.93 sec
# 5/5 [==============================] - 50s 7s/step - loss: 0.7057 - accuracy: 0.5694 - val_loss: 0.6392 - val_accuracy: 0.6875
# EfficientNetB6       trained in 49.79 sec
# 5/5 [==============================] - 48s 7s/step - loss: 0.7117 - accuracy: 0.5556 - val_loss: 0.6356 - val_accuracy: 0.6875
# EfficientNetB7       trained in 54.89 sec
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_resnet_v2/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 219055592/219055592 [==============================] - 5s 0us/step
# 5/5 [==============================] - 54s 9s/step - loss: 1.0314 - accuracy: 0.4861 - val_loss: 0.8144 - val_accuracy: 0.3750
# InceptionResNetV2    trained in 54.12 sec
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 1s 0us/step
# 5/5 [==============================] - 23s 4s/step - loss: 0.8172 - accuracy: 0.5625 - val_loss: 0.6308 - val_accuracy: 0.5625
# InceptionV3          trained in 23.02 sec
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf_no_top.h5
# 17225924/17225924 [==============================] - 0s 0us/step
# 5/5 [==============================] - 9s 1s/step - loss: 0.7299 - accuracy: 0.5694 - val_loss: 0.5984 - val_accuracy: 0.6875
# MobileNet            trained in 12.85 sec
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v3/weights_mobilenet_v3_large_224_1.0_float_no_top_v2.h5
# 12683000/12683000 [==============================] - 0s 0us/step
# 5/5 [==============================] - 9s 1s/step - loss: 0.7694 - accuracy: 0.5000 - val_loss: 0.6220 - val_accuracy: 0.6875
# MobileNetV3Large     trained in 14.16 sec
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v3/weights_mobilenet_v3_small_224_1.0_float_no_top_v2.h5
# 4334752/4334752 [==============================] - 0s 0us/step
# 5/5 [==============================] - 6s 673ms/step - loss: 0.6930 - accuracy: 0.5417 - val_loss: 0.6409 - val_accuracy: 0.6875
# MobileNetV3Small     trained in 8.62 sec
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/nasnet/NASNet-mobile-no-top.h5
# 19993432/19993432 [==============================] - 0s 0us/step
# 5/5 [==============================] - 33s 3s/step - loss: 0.6814 - accuracy: 0.6181 - val_loss: 0.4923 - val_accuracy: 0.7500
# NASNetMobile         trained in 37.04 sec
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet101_weights_tf_dim_ordering_tf_kernels_notop.h5
# 171446536/171446536 [==============================] - 1s 0us/step
# 5/5 [==============================] - 65s 12s/step - loss: 0.7162 - accuracy: 0.5972 - val_loss: 0.8431 - val_accuracy: 0.3125
# ResNet101            trained in 89.29 sec
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet101v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 171317808/171317808 [==============================] - 1s 0us/step
# 5/5 [==============================] - 59s 11s/step - loss: 0.6546 - accuracy: 0.6875 - val_loss: 0.4217 - val_accuracy: 0.8125
# ResNet101V2          trained in 88.33 sec
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet152_weights_tf_dim_ordering_tf_kernels_notop.h5
# 234698864/234698864 [==============================] - 2s 0us/step
# 5/5 [==============================] - 91s 16s/step - loss: 0.8174 - accuracy: 0.5278 - val_loss: 0.6282 - val_accuracy: 0.6875
# ResNet152            trained in 91.65 sec
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet152v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 234545216/234545216 [==============================] - 1s 0us/step
# 5/5 [==============================] - 85s 15s/step - loss: 0.8381 - accuracy: 0.5069 - val_loss: 0.5517 - val_accuracy: 0.6875
# ResNet152V2          trained in 85.08 sec
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 1s 0us/step
# 5/5 [==============================] - 33s 6s/step - loss: 0.7535 - accuracy: 0.5694 - val_loss: 0.6529 - val_accuracy: 0.6875
# ResNet50             trained in 44.59 sec
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94668760/94668760 [==============================] - 1s 0us/step
# 5/5 [==============================] - 29s 6s/step - loss: 0.7486 - accuracy: 0.6042 - val_loss: 0.5611 - val_accuracy: 0.7500
# ResNet50V2           trained in 28.73 sec
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step
# 5/5 [==============================] - 94s 18s/step - loss: 0.6832 - accuracy: 0.6111 - val_loss: 0.6937 - val_accuracy: 0.5000
# VGG16                trained in 145.87 sec
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 0s 0us/step
# 5/5 [==============================] - 115s 25s/step - loss: 0.6679 - accuracy: 0.5972 - val_loss: 0.6253 - val_accuracy: 0.6875
# VGG19                trained in 143.1 sec
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 [==============================] - 0s 0us/step
# 5/5 [==============================] - 38s 7s/step - loss: 0.7119 - accuracy: 0.5347 - val_loss: 0.6291 - val_accuracy: 0.6875
# Xception             trained in 38.17 sec

# %%
# Create a DataFrame with the results
models_result = []

for name, v in models.items():
    models_result.append([ name,
                          models[name]['train_accuracy'][-1],
                          models[name]['val_acc'][-1],
                          models[name]['perf']])

df_results = pd.DataFrame(models_result,
                          columns = ['model','train_accuracy','val_accuracy','Training time (sec)'])
df_results.sort_values(by='val_accuracy', ascending=False, inplace=True)
df_results.reset_index(inplace=True,drop=True)
df_results
# Out:
#                 model  train_accuracy  val_accuracy  Training time (sec)
# 0         DenseNet169          0.5278        0.8125                45.03
# 1         DenseNet201          0.6111        0.8125                93.22
# 2         ResNet101V2          0.6875        0.8125                88.33
# 3          ResNet50V2          0.6042        0.7500                28.73
# 4        NASNetMobile          0.6181        0.7500                37.04
# 5         DenseNet121          0.5486        0.6875                40.37
# 6           MobileNet          0.5694        0.6875                12.85
# 7               VGG19          0.5972        0.6875               143.10
# 8            ResNet50          0.5694        0.6875                44.59
# 9         ResNet152V2          0.5069        0.6875                85.08
# 10          ResNet152          0.5278        0.6875                91.65
# 11   MobileNetV3Small          0.5417        0.6875                 8.62
# 12   MobileNetV3Large          0.5000        0.6875                14.16
# 13           Xception          0.5347        0.6875                38.17
# 14        MobileNetV2          0.5000        0.6875                10.70
# 15     EfficientNetB7          0.5556        0.6875                54.89
# 16     EfficientNetB6          0.5694        0.6875                49.79
# 17     EfficientNetB4          0.5208        0.6875                55.68
# 18     EfficientNetB3          0.5694        0.6875                38.70
# 19     EfficientNetB2          0.4861        0.6875                30.78
# 20        InceptionV3          0.5625        0.5625                23.02
# 21              VGG16          0.6111        0.5000               145.87
# 22  InceptionResNetV2          0.4861        0.3750                54.12
# 23          ResNet101          0.5972        0.3125                89.29
# 24     EfficientNetB5          0.6042        0.3125                49.93
# 25     EfficientNetB1          0.5903        0.3125                30.15
# 26     EfficientNetB0          0.5417        0.3125                28.19

# %%
plt.figure(figsize = (15,5))
sns.barplot(x = 'model', y = 'val_accuracy', data = df_results)
plt.title('Accuracy on the Validation Set (after 1 epoch)', fontsize = 15)
plt.ylim(0,1)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize = (15,5))
sns.barplot(x = 'model', y = 'Training time (sec)', data = df_results)
plt.title('Training time for each model in sec', fontsize = 15)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize = (15,5))
sns.barplot(x = 'model', y = 'Training time (sec)', data = df_results)
plt.title('Training time for each model in sec', fontsize = 15)
plt.xticks(rotation=90)
plt.show()

# %%
# Load the pretained model
pretrained_model = tf.keras.applications.MobileNetV2(
    input_shape=(224, 224, 3),
    include_top=False,
    weights='imagenet',
    pooling='avg'
)

pretrained_model.trainable = False

# %%
inputs = pretrained_model.input

x = tf.keras.layers.Dense(128, activation='relu')(pretrained_model.output)
x = tf.keras.layers.Dense(128, activation='relu')(x)

outputs = tf.keras.layers.Dense(2, activation='softmax')(x)

model = tf.keras.Model(inputs=inputs, outputs=outputs)

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history = model.fit(
    train_images,
    validation_data=val_images,
    batch_size = 32,
    epochs=10,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(
            monitor='val_loss',
            patience=2,
            restore_best_weights=True
        )
    ]
)
# Out:
# Epoch 1/10
# 5/5 [==============================] - 11s 1s/step - loss: 0.9627 - accuracy: 0.5000 - val_loss: 0.6408 - val_accuracy: 0.6250
# Epoch 2/10
# 5/5 [==============================] - 8s 2s/step - loss: 0.6500 - accuracy: 0.5833 - val_loss: 0.6425 - val_accuracy: 0.7500
# Epoch 3/10
# 5/5 [==============================] - 5s 1s/step - loss: 0.5867 - accuracy: 0.6528 - val_loss: 0.6006 - val_accuracy: 0.6875
# Epoch 4/10
# 5/5 [==============================] - 5s 1s/step - loss: 0.5127 - accuracy: 0.7569 - val_loss: 0.5664 - val_accuracy: 0.7500
# Epoch 5/10
# 5/5 [==============================] - 7s 2s/step - loss: 0.4375 - accuracy: 0.7986 - val_loss: 0.5452 - val_accuracy: 0.8125
# Epoch 6/10
# 5/5 [==============================] - 6s 1s/step - loss: 0.3866 - accuracy: 0.8125 - val_loss: 0.5053 - val_accuracy: 0.8125
# Epoch 7/10
# 5/5 [==============================] - 5s 1s/step - loss: 0.3286 - accuracy: 0.8681 - val_loss: 0.4968 - val_accuracy: 0.6875
# Epoch 8/10
# 5/5 [==============================] - 7s 1s/step - loss: 0.2801 - accuracy: 0.9097 - val_loss: 0.5070 - val_accuracy: 0.7500
# Epoch 9/10
# 5/5 [==============================] - 5s 1s/step - loss: 0.2296 - accuracy: 0.9306 - val_loss: 0.4968 - val_accuracy: 0.6875
# Epoch 10/10
# 5/5 [==============================] - 7s 2s/step - loss: 0.2036 - accuracy: 0.9444 - val_loss: 0.4784 - val_accuracy: 0.7500

# %%
pd.DataFrame(history.history)[['accuracy','val_accuracy']].plot()
plt.title("Accuracy")
plt.show()

# %%
pd.DataFrame(history.history)[['loss','val_loss']].plot()
plt.title("Loss")
plt.show()

# %%
results = model.evaluate(test_images, verbose=0)

# %%
printmd(" ## Test Loss: {:.5f}".format(results[0]))
printmd("## Accuracy on the test set: {:.2f}%".format(results[1] * 100))
# Out:
#  ## Test Loss: 0.37617
# ## Accuracy on the test set: 83.33%

# %%
# Predict the label of the test_images
pred = model.predict(test_images)
pred = np.argmax(pred,axis=1)

# Map the label
labels = (train_images.class_indices)
labels = dict((v,k) for k,v in labels.items())
pred = [labels[k] for k in pred]

# Display the result
print(f'The first 2 predictions: {pred[:2]}')
# Out:
# 1/1 [==============================] - 1s 1s/step
# The first 2 predictions: ['ill', 'normal']

# %%
from sklearn.metrics import classification_report
y_test = list(test_df.Label)
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#          ill       1.00      0.67      0.80         9
#       normal       0.75      1.00      0.86         9
#
#     accuracy                           0.83        18
#    macro avg       0.88      0.83      0.83        18
# weighted avg       0.88      0.83      0.83        18

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

cf_matrix = confusion_matrix(y_test, pred, normalize='true')
plt.figure(figsize = (10,6))
sns.heatmap(cf_matrix, annot=True, xticklabels = sorted(set(y_test)), yticklabels = sorted(set(y_test)))
plt.title('Normalized Confusion Matrix')
plt.show()

# %%
# Display some pictures of the dataset with their labels and the predictions
fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(15, 15),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(test_df.Filepath.iloc[i]))
    ax.set_title(f"True: {test_df.Label.iloc[i]}\nPredicted: {pred[i]}")
plt.tight_layout()
plt.show()

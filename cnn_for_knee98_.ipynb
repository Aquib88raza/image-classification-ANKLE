# %% [markdown]
# <a href="https://colab.research.google.com/github/Aquib88raza/image-classification-ANKLE/blob/main/cnn_for_knee98_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np
import cv2
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.optimizers import Adam

# %%
normal_path = "/content/drive/MyDrive/knee osteo/healthy"
ill_path = "/content/drive/MyDrive/knee osteo/ill"

main_folders = [normal_path, ill_path]

images = []
labels = []

# Resizing function
def resize_image(img):
    resized_img = cv2.resize(img, (64, 64))  # Resizing to a common shape
    return resized_img

for idx, folder in enumerate(main_folders):
    if os.path.exists(folder):
        image_files = [file for file in os.listdir(folder) if file.endswith('.jpg')]
        if image_files:
            for image_file in image_files:
                image_path = os.path.join(folder, image_file)
                image = cv2.imread(image_path)
                if image is not None:
                    image = resize_image(image)  # Resize the image
                    images.append(image)
                    labels.append(idx)
                else:
                    print(f"Error loading image: {image_path}")
        else:
            print(f"No JPG images found in: {folder}")
    else:
        print(f"Directory does not exist: {folder}")

if images:
    images = np.array(images)
    labels = np.array(labels)

    # Normalize pixel values to be between 0 and 1
    images = images.astype('float32') / 255.0

    print(f"Total number of images: {len(images)}")

    X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=0.2, random_state=42)
    print(f"Number of training images: {len(X_train)}")
    print(f"Number of testing images: {len(X_test)}")
# Out:
# Total number of images: 603
# Number of training images: 482
# Number of testing images: 121

# %%
# Define the model
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(64, 64, 3)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(1, activation='sigmoid'))  # Assuming binary classification

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# Train the model
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))

model.summary()
# Out:
# Epoch 1/50
# 16/16 [==============================] - 4s 192ms/step - loss: 0.8573 - accuracy: 0.5394 - val_loss: 0.7009 - val_accuracy: 0.4711
# Epoch 2/50
# 16/16 [==============================] - 4s 250ms/step - loss: 0.6919 - accuracy: 0.5021 - val_loss: 0.6918 - val_accuracy: 0.5289
# Epoch 3/50
# 16/16 [==============================] - 3s 175ms/step - loss: 0.6924 - accuracy: 0.5353 - val_loss: 0.6919 - val_accuracy: 0.4711
# Epoch 4/50
# 16/16 [==============================] - 2s 145ms/step - loss: 0.6910 - accuracy: 0.5083 - val_loss: 0.6956 - val_accuracy: 0.4711
# Epoch 5/50
# 16/16 [==============================] - 2s 144ms/step - loss: 0.6843 - accuracy: 0.5685 - val_loss: 0.6901 - val_accuracy: 0.4711
# Epoch 6/50
# 16/16 [==============================] - 2s 146ms/step - loss: 0.6764 - accuracy: 0.6037 - val_loss: 0.6710 - val_accuracy: 0.5950
# Epoch 7/50
# 16/16 [==============================] - 3s 200ms/step - loss: 0.6784 - accuracy: 0.5892 - val_loss: 0.6623 - val_accuracy: 0.6777
# Epoch 8/50
# 16/16 [==============================] - 4s 252ms/step - loss: 0.6598 - accuracy: 0.6079 - val_loss: 0.7247 - val_accuracy: 0.4711
# Epoch 9/50
# 16/16 [==============================] - 3s 154ms/step - loss: 0.6694 - accuracy: 0.6058 - val_loss: 0.6989 - val_accuracy: 0.4793
# Epoch 10/50
# 16/16 [==============================] - 2s 150ms/step - loss: 0.6692 - accuracy: 0.5685 - val_loss: 0.8637 - val_accuracy: 0.5289
# Epoch 11/50
# 16/16 [==============================] - 2s 149ms/step - loss: 0.6910 - accuracy: 0.5830 - val_loss: 0.7121 - val_accuracy: 0.5372
# Epoch 12/50
# 16/16 [==============================] - 2s 149ms/step - loss: 0.6570 - accuracy: 0.6266 - val_loss: 0.6225 - val_accuracy: 0.6860
# Epoch 13/50
# 16/16 [==============================] - 3s 223ms/step - loss: 0.5845 - accuracy: 0.6971 - val_loss: 0.6409 - val_accuracy: 0.5785
# Epoch 14/50
# 16/16 [==============================] - 4s 261ms/step - loss: 0.5637 - accuracy: 0.6950 - val_loss: 0.8069 - val_accuracy: 0.5207
# Epoch 15/50
# 16/16 [==============================] - 2s 151ms/step - loss: 0.5403 - accuracy: 0.7324 - val_loss: 0.7208 - val_accuracy: 0.5537
# Epoch 16/50
# 16/16 [==============================] - 2s 152ms/step - loss: 0.5140 - accuracy: 0.7510 - val_loss: 0.4500 - val_accuracy: 0.8512
# Epoch 17/50
# 16/16 [==============================] - 3s 161ms/step - loss: 0.4234 - accuracy: 0.8299 - val_loss: 0.4030 - val_accuracy: 0.8595
# Epoch 18/50
# 16/16 [==============================] - 3s 158ms/step - loss: 0.3571 - accuracy: 0.8797 - val_loss: 0.3743 - val_accuracy: 0.8760
# Epoch 19/50
# 16/16 [==============================] - 4s 253ms/step - loss: 0.3669 - accuracy: 0.8506 - val_loss: 0.4115 - val_accuracy: 0.8099
# Epoch 20/50
# 16/16 [==============================] - 3s 207ms/step - loss: 0.3321 - accuracy: 0.8672 - val_loss: 0.3970 - val_accuracy: 0.8099
# Epoch 21/50
# 16/16 [==============================] - 3s 163ms/step - loss: 0.3668 - accuracy: 0.8465 - val_loss: 0.3877 - val_accuracy: 0.8430
# Epoch 22/50
# 16/16 [==============================] - 2s 155ms/step - loss: 0.2765 - accuracy: 0.9212 - val_loss: 0.4092 - val_accuracy: 0.7934
# Epoch 23/50
# 16/16 [==============================] - 2s 152ms/step - loss: 0.3451 - accuracy: 0.8320 - val_loss: 0.3969 - val_accuracy: 0.8264
# Epoch 24/50
# 16/16 [==============================] - 3s 191ms/step - loss: 0.2614 - accuracy: 0.8817 - val_loss: 0.2918 - val_accuracy: 0.8760
# Epoch 25/50
# 16/16 [==============================] - 4s 259ms/step - loss: 0.2610 - accuracy: 0.8921 - val_loss: 0.3304 - val_accuracy: 0.8264
# Epoch 26/50
# 16/16 [==============================] - 3s 160ms/step - loss: 0.2086 - accuracy: 0.9170 - val_loss: 0.2308 - val_accuracy: 0.9256
# Epoch 27/50
# 16/16 [==============================] - 3s 162ms/step - loss: 0.1898 - accuracy: 0.9295 - val_loss: 0.2604 - val_accuracy: 0.8760
# Epoch 28/50
# 16/16 [==============================] - 3s 161ms/step - loss: 0.2157 - accuracy: 0.9212 - val_loss: 0.2306 - val_accuracy: 0.9091
# Epoch 29/50
# Epoch 48/50
# 16/16 [==============================] - 3s 197ms/step - loss: 0.0658 - accuracy: 0.9710 - val_loss: 0.1173 - val_accuracy: 0.9504
# Epoch 49/50
# 16/16 [==============================] - 3s 160ms/step - loss: 0.0613 - accuracy: 0.9876 - val_loss: 0.0915 - val_accuracy: 0.9587
# Epoch 50/50
# 16/16 [==============================] - 3s 161ms/step - loss: 0.0584 - accuracy: 0.9813 - val_loss: 0.1042 - val_accuracy: 0.9587
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_10 (Conv2D)          (None, 62, 62, 32)        896
#
#  max_pooling2d_10 (MaxPooli  (None, 31, 31, 32)        0
#  ng2D)
#
#  conv2d_11 (Conv2D)          (None, 29, 29, 64)        18496
#
#  max_pooling2d_11 (MaxPooli  (None, 14, 14, 64)        0
#  ng2D)
#
#  flatten_5 (Flatten)         (None, 12544)             0
#
#  dense_10 (Dense)            (None, 64)                802880
#
#  dense_11 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params: 822337 (3.14 MB)
# Trainable params: 822337 (3.14 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
# Predict labels on the test set
y_pred = model.predict(X_test)
y_pred = np.round(y_pred).flatten()

# Classification Report
print("Classification Report:")
print(classification_report(y_test, y_pred))

# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred)

# Display Confusion Matrix using Seaborn
plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix, annot=True, cmap='Blues', fmt='d', cbar=False,
            xticklabels=['Healthy', 'Ill'], yticklabels=['Healthy', 'Ill'])
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 4/4 [==============================] - 0s 38ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96        64
#            1       0.96      0.95      0.96        57
#
#     accuracy                           0.96       121
#    macro avg       0.96      0.96      0.96       121
# weighted avg       0.96      0.96      0.96       121

# %%
# Extracting training and validation accuracy and loss from history
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
train_loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(train_acc) + 1)

# Plotting the training and validation accuracy
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs, train_acc, 'b', label='Training Accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plotting the training and validation loss
plt.subplot(1, 2, 2)
plt.plot(epochs, train_loss, 'b', label='Training Loss')
plt.plot(epochs, val_loss, 'r', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Predict labels on the training set
y_train_pred = model.predict(X_train)
y_train_pred = np.round(y_train_pred).flatten()

# Classification Report for training data
print("Classification Report - Training Data:")
print(classification_report(y_train, y_train_pred))
# Confusion Matrix
conf_matrix = confusion_matrix(y_train, y_train_pred)

# Display Confusion Matrix using Seaborn
plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix, annot=True, cmap='Blues', fmt='d', cbar=False,
            xticklabels=['Healthy', 'Ill'], yticklabels=['Healthy', 'Ill'])
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 16/16 [==============================] - 1s 41ms/step
# Classification Report - Training Data:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       238
#            1       1.00      0.98      0.99       244
#
#     accuracy                           0.99       482
#    macro avg       0.99      0.99      0.99       482
# weighted avg       0.99      0.99      0.99       482

# %%
import random

# Predict labels on the test set
y_pred = model.predict(X_test)
y_pred = np.round(y_pred).flatten()

# Randomly select some images for display (e.g., 10 images)
num_samples_to_display = 10
random_indices = random.sample(range(len(X_test)), num_samples_to_display)

# Create a figure to display the images
plt.figure(figsize=(10, 10))
plt.suptitle("True vs. Predicted Images")

# Define the number of rows and columns for image display
num_rows = 5
num_cols = 2

for i, index in enumerate(random_indices):
    plt.subplot(num_rows, num_cols, i + 1)
    plt.imshow(X_test[index])  # Display the image
    true_label = "Healthy" if y_test[index] == 0 else "Ill"
    predicted_label = "Healthy" if y_pred[index] == 0 else "Ill"  # Use y_pred instead of y_test_pred
    plt.title(f"True: {true_label}\nPredicted: {predicted_label}")

plt.tight_layout()
plt.show()
# Out:
# 4/4 [==============================] - 0s 69ms/step

# %% [markdown]
# <a href="https://colab.research.google.com/github/Aquib88raza/image-classification-ANKLE/blob/main/cnn_for_knee.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np
import cv2
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.optimizers import Adam

# %%
normal_path = "/content/drive/MyDrive/knee osteo/healthy"
ill_path = "/content/drive/MyDrive/knee osteo/ill"

main_folders = [normal_path, ill_path]

images = []
labels = []

# Resizing function
def resize_image(img):
    resized_img = cv2.resize(img, (64, 64))  # Resizing to a common shape
    return resized_img

for idx, folder in enumerate(main_folders):
    if os.path.exists(folder):
        image_files = [file for file in os.listdir(folder) if file.endswith('.jpg')]
        if image_files:
            for image_file in image_files:
                image_path = os.path.join(folder, image_file)
                image = cv2.imread(image_path)
                if image is not None:
                    image = resize_image(image)  # Resize the image
                    images.append(image)
                    labels.append(idx)
                else:
                    print(f"Error loading image: {image_path}")
        else:
            print(f"No JPG images found in: {folder}")
    else:
        print(f"Directory does not exist: {folder}")

if images:
    images = np.array(images)
    labels = np.array(labels)

    # Normalize pixel values to be between 0 and 1
    images = images.astype('float32') / 255.0

    print(f"Total number of images: {len(images)}")

    X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=0.2, random_state=42)
    print(f"Number of training images: {len(X_train)}")
    print(f"Number of testing images: {len(X_test)}")
# Out:
# Total number of images: 603
# Number of training images: 482
# Number of testing images: 121

# %%
# Define the model
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(64, 64, 3)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(1, activation='sigmoid'))  # Assuming binary classification

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# Train the model
model.fit(X_train, y_train, epochs=20, batch_size=32, validation_data=(X_test, y_test))

model.summary()
# Out:
# Epoch 1/20
# 16/16 [==============================] - 4s 171ms/step - loss: 0.7491 - accuracy: 0.5104 - val_loss: 0.6922 - val_accuracy: 0.5289
# Epoch 2/20
# 16/16 [==============================] - 2s 157ms/step - loss: 0.6956 - accuracy: 0.4979 - val_loss: 0.6922 - val_accuracy: 0.5289
# Epoch 3/20
# 16/16 [==============================] - 3s 206ms/step - loss: 0.6936 - accuracy: 0.4938 - val_loss: 0.6915 - val_accuracy: 0.5289
# Epoch 4/20
# 16/16 [==============================] - 4s 249ms/step - loss: 0.6906 - accuracy: 0.5415 - val_loss: 0.6965 - val_accuracy: 0.4711
# Epoch 5/20
# 16/16 [==============================] - 2s 146ms/step - loss: 0.6981 - accuracy: 0.5062 - val_loss: 0.6940 - val_accuracy: 0.4711
# Epoch 6/20
# 16/16 [==============================] - 3s 158ms/step - loss: 0.6919 - accuracy: 0.5083 - val_loss: 0.6909 - val_accuracy: 0.5702
# Epoch 7/20
# 16/16 [==============================] - 2s 146ms/step - loss: 0.6898 - accuracy: 0.5124 - val_loss: 0.6881 - val_accuracy: 0.5289
# Epoch 8/20
# 16/16 [==============================] - 2s 151ms/step - loss: 0.6817 - accuracy: 0.6971 - val_loss: 0.6860 - val_accuracy: 0.4711
# Epoch 9/20
# 16/16 [==============================] - 4s 228ms/step - loss: 0.6889 - accuracy: 0.5083 - val_loss: 0.6843 - val_accuracy: 0.4711
# Epoch 10/20
# 16/16 [==============================] - 4s 246ms/step - loss: 0.6674 - accuracy: 0.5892 - val_loss: 0.6913 - val_accuracy: 0.5289
# Epoch 11/20
# 16/16 [==============================] - 3s 158ms/step - loss: 0.6556 - accuracy: 0.6349 - val_loss: 0.6730 - val_accuracy: 0.5041
# Epoch 12/20
# 16/16 [==============================] - 3s 160ms/step - loss: 0.6559 - accuracy: 0.5996 - val_loss: 0.6493 - val_accuracy: 0.5620
# Epoch 13/20
# 16/16 [==============================] - 3s 166ms/step - loss: 0.6086 - accuracy: 0.6950 - val_loss: 0.7190 - val_accuracy: 0.5041
# Epoch 14/20
# 16/16 [==============================] - 3s 164ms/step - loss: 0.6375 - accuracy: 0.6017 - val_loss: 0.6627 - val_accuracy: 0.5041
# Epoch 15/20
# 16/16 [==============================] - 4s 253ms/step - loss: 0.5640 - accuracy: 0.7324 - val_loss: 0.6040 - val_accuracy: 0.5868
# Epoch 16/20
# 16/16 [==============================] - 3s 186ms/step - loss: 0.5163 - accuracy: 0.7946 - val_loss: 0.6024 - val_accuracy: 0.6198
# Epoch 17/20
# 16/16 [==============================] - 2s 150ms/step - loss: 0.4739 - accuracy: 0.8008 - val_loss: 0.5282 - val_accuracy: 0.7025
# Epoch 18/20
# 16/16 [==============================] - 3s 160ms/step - loss: 0.4433 - accuracy: 0.8071 - val_loss: 0.4043 - val_accuracy: 0.8347
# Epoch 19/20
# 16/16 [==============================] - 2s 150ms/step - loss: 0.3489 - accuracy: 0.8734 - val_loss: 0.3869 - val_accuracy: 0.8678
# Epoch 20/20
# 16/16 [==============================] - 3s 203ms/step - loss: 0.3239 - accuracy: 0.9046 - val_loss: 0.2995 - val_accuracy: 0.9091
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 62, 62, 32)        896
#
#  max_pooling2d_8 (MaxPoolin  (None, 31, 31, 32)        0
#  g2D)
#
#  conv2d_9 (Conv2D)           (None, 29, 29, 64)        18496
#
#  max_pooling2d_9 (MaxPoolin  (None, 14, 14, 64)        0
#  g2D)
#
#  flatten_4 (Flatten)         (None, 12544)             0
#
#  dense_8 (Dense)             (None, 64)                802880
#
#  dense_9 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 822337 (3.14 MB)
# Trainable params: 822337 (3.14 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
# Predict labels on the test set
y_pred = model.predict(X_test)
y_pred = np.round(y_pred).flatten()

# Classification Report
print("Classification Report:")
print(classification_report(y_test, y_pred))

# Confusion Matrix
conf_matrix = confusion_matrix(y_test, y_pred)

# Display Confusion Matrix using Seaborn
plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix, annot=True, cmap='Blues', fmt='d', cbar=False,
            xticklabels=['Healthy', 'Ill'], yticklabels=['Healthy', 'Ill'])
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 4/4 [==============================] - 0s 44ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.95      0.92        64
#            1       0.94      0.86      0.90        57
#
#     accuracy                           0.91       121
#    macro avg       0.91      0.91      0.91       121
# weighted avg       0.91      0.91      0.91       121

# %%
# Extracting training and validation accuracy and loss from history
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
train_loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(train_acc) + 1)

# Plotting the training and validation accuracy
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs, train_acc, 'b', label='Training Accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plotting the training and validation loss
plt.subplot(1, 2, 2)
plt.plot(epochs, train_loss, 'b', label='Training Loss')
plt.plot(epochs, val_loss, 'r', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()
